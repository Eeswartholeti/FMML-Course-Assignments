# %% [markdown]
# <a href="https://colab.research.google.com/github/Eeswartholeti/FMML-Course-Assignments/blob/main/Module_8_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 06:38:39--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   190MB/s    in 0.4s
#
# 2023-05-04 06:38:40 (190 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 252  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6330   1611.04069v2  Sparsity-based approaches have been popular in...  stat
# 14640   0707.3269v1  This paper describes the Linguistic Annotation...    cs
# 11496  1603.06743v3  We introduce the localized Lasso, which is sui...  stat
# 32343  1502.03601v1  Bankruptcy is a legal procedure that claims a ...    cs
# 18916   1301.2289v1  Many real life domains contain a mixture of di...    cs
# ...             ...                                                ...   ...
# 20058   1404.6883v1  Argumentation is one of the most popular appro...    cs
# 11761  1611.06265v2  Deep clustering is the first method to handle ...  stat
# 6738   1705.09236v1  We design and analyse variations of the classi...  stat
# 2816   1802.00981v1  We consider an extension of the contextual ban...    cs
# 27131  1702.04663v1  Handwritten character recognition is an active...    cs
#
#                                                    title  year  \
# 6330   Low-rank and Adaptive Sparse Signal (LASSI) Mo...  2016
# 14640  International Standard for a Linguistic Annota...  2007
# 11496    Localized Lasso for High-Dimensional Regression  2016
# 32343  A Predictive System for detection of Bankruptc...  2015
# 18916  Exact Inference in Networks with Discrete Chil...  2013
# ...                                                  ...   ...
# 20058  Credulous and Skeptical Argument Games for Com...  2014
# 11761  Deep Clustering and Conventional Networks for ...  2016
# 6738   Asynchronous Parallel Bayesian Optimisation vi...  2017
# 2816   Adaptive Representation Selection in Contextua...  2018
# 27131  Handwritten Arabic Numeral Recognition using D...  2017
#
#                                                 keywords
# 6330   [approaches, applications, processing, compres...
# 14640  [describes, linguistic, annotation, framework,...
# 11496  [introduce, localized, interpretable, predicti...
# 32343  [bankruptcy, procedure, organization, essentia...
# 18916  [continuous, variables, animportant, condition...
# ...                                                  ...
# 20058  [argumentation, approaches, monotonic, formali...
# 11761  [clustering, separation, scenarios, arbitrary,...
# 6738   [variations, classical, procedure, optimisatio...
# 2816   [extension, contextual, motivated, practical, ...
# 27131  [handwritten, character, recognition, applicat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6330     [approaches, applications, processing, compres...
# 14640    [describes, linguistic, annotation, framework,...
# 11496    [introduce, localized, interpretable, predicti...
# 32343    [bankruptcy, procedure, organization, essentia...
# 18916    [continuous, variables, animportant, condition...
#                                ...
# 9754     [attributes, compromise, anonymous, sensitive,...
# 22398    [hyperparameters, regression, specified, estim...
# 22867    [principal, component, dimension, reduction, s...
# 14801    [distribution, complexities, indigenous, unifo...
# 11065    [discriminant, functional, regression, present...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8766 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="34de822f-f433-4119-baf7-8d7edeb06e0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34de822f-f433-4119-baf7-8d7edeb06e0e")) {                    Plotly.newPlot(                        "34de822f-f433-4119-baf7-8d7edeb06e0e",                        [{"x":["performance","measurements","penalized","experiments","demonstrate","investigate","components","estimation","spatiotemporal","techniques","estimating","decomposed","accelerated","reconstruction","estimated","underlying","applications","resonance","component","promising","transform","demonstrated","processing","numerical","dictionary","formulations","efficient","compressed","undersampled","extension","resulting","approaches","development","describes","developing","international","annotation","resources","framework","linguistic","regularization","predictive","outperform","regression","interpretable","introduce","exclusive","empirically","alternatives","diversity","procedure","iterative","guaranteed","dimensional","similarity","personalized","localized","dimensionality","optimization","specifically","parameter","simulated","categorize","detection","organization","different","companies","perspective","prediction","financial","essential","computing","ascertain","augmented","integration","assignment","inference","gaussians","dependencies","distributions","distribution","comparable","algorithm","substantially","variables","approximation","particularly","continuous","conditional","multivariate","approximate","generalize","providing","algorithms","implement","complexity","conflicts","calculated","determine","occurring","introduced","associates","association","instances","necessary","sometimes","transitions","particular","clustering","configurable","neuroscience","addresses","developed","architectures","cognitive","additionally","challenging","preliminary","diagnostic","competitively","intelligence","accomplishes","architecture","artificial","reasoning","tradition","psychology","progressively","currently","generated","inferring","communications","relationship","delivering","regulations","ubiquitous","technologies","collecting","locations","classification","population","activities","information","obtaining","understanding","knowledge","dependence","inferential","prospective","expressions","dirichlet","posterior","reliability","incomplete","questions","alternative","discussed","inductive","approximated","categorical","selection","analytical","stochastic","expression","descriptive","significantly","approximations","corresponding","observation","viewpoints","computation","calibrating","therefore","momentary","equivalently","projecting","exploiting","following","appearance","synchronized","extracted","processes","transformations","properties","geometrical","classifier","classifiers","preservation","characteristics","encouraging","topological","accuracies","interaction","progresses","exploitation","dynamically","technique","clusterings","advertisement","contextual"],"y":[874,44,3,620,562,149,130,193,14,407,56,8,17,115,62,129,457,18,108,105,69,97,296,85,66,14,416,36,3,67,146,417,124,100,67,15,67,60,552,71,79,58,85,104,43,310,4,65,23,49,146,81,39,178,129,13,16,55,325,159,127,53,3,317,17,734,8,63,219,6,72,116,4,37,51,36,227,6,48,105,234,101,840,32,122,130,74,120,86,19,114,42,108,596,57,241,8,26,83,25,134,3,28,89,74,27,18,262,150,4,16,47,224,122,62,53,268,56,14,4,93,2,257,141,119,4,13,9,61,195,26,5,74,3,2,15,31,16,39,483,41,34,702,33,170,349,23,5,5,44,28,37,24,37,78,111,54,13,18,16,185,15,138,55,12,261,36,149,71,19,155,2,135,1,6,10,92,95,66,3,115,113,42,216,11,159,104,8,99,20,24,24,86,4,34,32,249,3,4,53],"type":"bar"},{"x":["performance","measurements","penalized","experiments","demonstrate","investiga ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>Translating</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.8888888888888888);'>Segmenting</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Multimodal</span> <span style=''>Medical</span> <span style=''>Volumes</span> <span style=''>with</span> <span style=''>Cycle</span> <span style=''>and</span> <span style=''>Shape</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Consistency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Network</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Synthesized</span> <span style=''>medical</span> <span style=''>images</span> <span style=''>have</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>eg</span> <span style=''>as</span> <span style=''>an</span> <span style=''>intermedium</span> <span style=''>in</span> <span style=''>cross</span> <span style=''>modality</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8709677419354838);'>registration</span> <span style=''>and</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>supplementary</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>to</span> <span style=''>boost</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.46478873239436624);'>capability</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Especially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthesized</span> <span style=''>computed</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>tomography</span> <span style=''>(CT)</span> <span style=''>data</span> <span style=''>can</span> <span style=''>provide</span> <span style=''>X</span> <span style=''>ray</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>attenuation</span> <span style=''>map</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>radiation</span> <span style=''>therapy</span> <span style=''>planning</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>cross</span> <span style=''>modality</span> <span style='background-color:rgba(0, 255, 0, 0.6610169491525424);'>synthesis</span> <span style=''>approach</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3194444444444444);'>following</span> <span style=''>targets</span> <span style=''>1)</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>synthesizing</span> <span style='background-color:rgba(0, 255, 0, 0.3469387755102041);'>realistic</span> <span style=''>looking</span> <span style=''>3D</span> <span style=''>images</span> <span style=''>using</span> <span style=''>unpaired</span> <span style=''>training</span> <span style=''>data</span> <span style=''>2)</span> <span style=''>ensuring</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636365);'>anatomical</span> <span style='background-color:rgba(0, 255, 0, 0.31858407079646023);'>structures</span> <span style=''>which</span> <span style=''>could</span> <span style=''>be</span> <span style=''>changed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0. ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoregressive</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>time</span> <span style=''>series</span> <span style=''>under</span> <span style=''>a</span> <span style=''>doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>d</span> <span style=''>to</span> <span style=''>scale</span> <span style=''>with</span> <span style=''>the</span> <span style=''>series</span> <span style=''>length</span> <span style=''>T</span> <span style=''>We</span> <span style=''>treat</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>time</span> <span style=''>series</span> <span style=''>as</span> <span style=''>a</span> <span style=''>nuisance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>and</span> <span style=''>directly</span> <span style=''>apply</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>time</span> <span style=''>series</span> <span style=''>as</span> <span style=''>if</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>explicit</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style=''>rates</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>for</span> <span style=''>leading</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>extend</span> <span style=''>this</span> <span style=''>result</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>Our</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrates</span> <span style=''>that</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>norm</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>matrix</span> <span style=''>plays</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>role</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Solving</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.347985347985348);'>dimensional</span> <span style=''>committor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.4842105263157894);'>artificial</span> <span style=''>neural</span> <span style=''>networks</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>note</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.4842105263157894);'>artificial</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>to</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>between</span> <span style=''>states</span> <span style=''>governed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3218673218673218);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.39285714285714285);'>numerical</span> <span style=''>schemes</span> <span style=''>for</span> <span style=''>the</span> <span style=''>committor</span> <span style=''>function</span> <span style=''>the</span> <span style=''>central</span> <span style=''>object</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>path</span> <span style=''>theory</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3499999999999999);'>satisfies</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.347985347985348);'>dimensional</span> <span style=''>Fokker</span> <span style=''>Planck</span> <span style=''>equation</span> <span style=''>By</span> <span style=''>working</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6153846153846154);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>such</span> <span style=''>partial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style=''>equation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>parameterizing</span> <span style=''>the</span> <span style=''>committor</span> <span style=''>function</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.4049586776859504);'>approximations</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>weights</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3218673218673218);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.39285714285714285);'>numerical</span> <span style=''>examples</span> <span style=''>show</span> <span style=''>that</span> <span style=''>moderate</span> <span style=''>accuracy</span> <span style=''>can</span> <span style=''>be</span> <span style=''>achieved</span> <span style=''>for</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Attention</span> <span style=''>based</span> <span style=''>Graph</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>for</span> <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>Learning</span> <br/><br/><span style=''>Recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>popularized</span> <span style=''>graph</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>achieve</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>accuracy</span> <span style=''>on</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>for</span> <span style=''>graph</span> <span style=''>based</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>over</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternate</span> <span style=''>between</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>layer</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregates</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>states</span> <span style=''>of</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style=''>and</span> <span style=''>a</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>layer</span> <span style=''>Perhaps</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprisingly</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>that</span> <span style=''>removes</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intermediate</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>layers</span> <span style=''>is</span> <span style=''>still</span> <span style=''>able</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparable</span> <span style=''>to</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>models</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>which</span> <span style=''>is</span> <span style=''>critical</span> <span style=''>for</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>where</span> <span style=''>number</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>examp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10590339892665473)
# 	knowledge (0.12486583184257603)
# 	experimental (0.13595706618962433)
# 	segmentation (0.06976744186046512)
# 	information (0.25116279069767444)
# 	architecture (0.09194991055456171)
# 	detection (0.11341681574239713)
# 	different (0.2626118067978533)
# 	convolutional (0.13023255813953488)
# 	recognition (0.13381037567084078)
#
# Some Statistics words are:
# 	stochastic (0.1341645885286783)
# 	distributions (0.12668329177057355)
# 	theoretical (0.1456359102244389)
# 	statistical (0.15311720698254364)
# 	variables (0.142643391521197)
# 	distribution (0.18403990024937655)
# 	estimation (0.17306733167082294)
# 	dimensional (0.18354114713216957)
# 	inference (0.20548628428927682)
# 	regression (0.16957605985037408)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6c981383-3743-4a82-97dc-8abb40d4ee46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c981383-3743-4a82-97dc-8abb40d4ee46")) {                    Plotly.newPlot(                        "6c981383-3743-4a82-97dc-8abb40d4ee46",                        [{"x":["performance","measurements","penalized","experiments","demonstrate","investigate","components","estimation","spatiotemporal","techniques","estimating","decomposed","accelerated","reconstruction","estimated","underlying","applications","resonance","component","promising","transform","demonstrated","processing","numerical","dictionary","formulations","efficient","compressed","undersampled","extension","resulting","approaches","development","describes","developing","international","annotation","resources","framework","linguistic","regularization","predictive","outperform","regression","interpretable","introduce","exclusive","empirically","alternatives","diversity","procedure","iterative","guaranteed","dimensional","similarity","personalized","localized","dimensionality","optimization","specifically","parameter","simulated","categorize","detection","organization","different","companies","perspective","prediction","financial","essential","computing","ascertain","augmented","integration","assignment","inference","gaussians","dependencies","distributions","distribution","comparable","algorithm","substantially","variables","approximation","particularly","continuous","conditional","multivariate","approximate","generalize","providing","algorithms","implement","complexity","conflicts","calculated","determine","occurring","introduced","associates","association","instances","necessary","sometimes","transitions","particular","clustering","configurable","neuroscience","addresses","developed","architectures","cognitive","additionally","challenging","preliminary","diagnostic","competitively","intelligence","accomplishes","architecture","artificial","reasoning","tradition","psychology","progressively","currently","generated","inferring","communications","relationship","delivering","regulations","ubiquitous","technologies","collecting","locations","classification","population","activities","information","obtaining","understanding","knowledge","dependence","inferential","prospective","expressions","dirichlet","posterior","reliability","incomplete","questions","alternative","discussed","inductive","approximated","categorical","selection","analytical","stochastic","expression","descriptive","significantly","approximations","corresponding","observation","viewpoints","computation","calibrating","therefore","momentary","equivalently","projecting","exploiting","following","appearance","synchronized","extracted","processes","transformations","properties","geometrical","classifier","classifiers","preservation","characteristics","encouraging","topological","accuracies","interaction","progresses","exploitation","dynamically","technique","clusterings","advertisement","contextual","collaborative","recommendation","scalability","classical","increased","strategies","filtering","exploration","computational","preference","advantage","empirical","consideration","nonlinear","structure","otherwise","difficult","consistent","accordingly","tightening","regularizer","connection","maximizes","divergence","mechanics","equivalent","suggested","regularized","including","extensive","exponential","adversary","previously","environments","sensitive","rationality","imaginary","theoretic","constraints","adversarial","justified","equilibrium","interpretation","statistical","interactions","significant","anomalous","involving","exhibited","simultaneously","correspond","relations","capabilities","nonparametric","explicitly","considerable ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	realizable
# 	centering
# 	ingenious
# 	bernsteins
# 	minimises
# 	intimately
# 	truncation
# 	tremendously
# 	nonconjugate
# 	embarrassingly
# 	generalising
# 	convincingly
# 	supernova
# 	bernstein
# 	multipartite
# 	verifiable
# 	anchoring
# 	resolvable
# 	mcallester
# 	kontorovich
# Some words which never appear in Statistics papers:
# 	configurable
# 	accomplishes
# 	descriptive
# 	synchronized
# 	processor
# 	conceptnet
# 	substituted
# 	commonsense
# 	taxonomies
# 	symbiotic
# 	beautiful
# 	photography
# 	colorizing
# 	monocular
# 	suppression
# 	pervasively
# 	transmitted
# 	laborious
# 	localizing
# 	conversations

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075598203850649e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
